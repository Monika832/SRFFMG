# %%
import cv2
import matplotlib.pyplot as plt

# %%
from inference import load_model,upscale_image_and_convert

# %%
model = load_model("srffmg.pb")

# %%
original,upscaled = upscale_image_and_convert(model,"Dataset/test_Set/LR/00012.jpg")

# %%
plt.figure(figsize=(12,8))
plt.subplot(1,3,1)
plt.imshow(original[:,:,::-1])
plt.subplot(1,3,2)
plt.imshow(upscaled[:,:,::-1])
