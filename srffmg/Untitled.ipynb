# %%
import cv2
import matplotlib.pyplot as plt

# %%
sr = cv2.dnn_superres.DnnSuperResImpl_create()
img = cv2.imread("Dataset/test_Set/LR/00529.jpg") 
path = "srffmg.pb"
 
sr.readModel(path)
 
sr.setModel("lapsrn",8)
 
result = sr.upsample(img)
 
plt.figure(figsize=(12,8))
plt.subplot(1,3,1)
# Original image
img = cv2.imread("Dataset/test_Set/LR35/00529.jpg")
plt.imshow(img[:,:,::-1])
plt.subplot(1,3,2)
# SR upscaled
plt.imshow(result[:,:,::-1])

#Hr image
